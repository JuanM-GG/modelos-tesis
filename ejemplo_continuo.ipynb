# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanM-GG/modelos-tesis/blob/main/ejemplo_continuo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Título:
#
# Nombre:
#
# Fecha:

# %% [markdown]
# Cargar librerías

# %%
install.packages("deSolve")
library(deSolve)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# Declarar la función

# %%
# parámetros 
k1 = 0.8877
k2 = 0.2320
k3 = 1.8260 
Caf = 100

# %%
objective <- function(D){

    P = (k1/(D+k2))*((-(D+k1) + sqrt((D+k1)^2 + 4*D*Caf*k3))/2*k3)
   

    return(P)
}

# %%
D = seq(0,1,0.01)
Pb = objective(D)

# %%
par(mar = c(5,7,4,2) + 0.1)
plot(D, Pb, type = "l", lwd = 4, cex.axis = 2, cex.lab = 2, col = "darkblue", xlab = "D (1/min)",
      ylab = expression(paste(P[C[B]]," (mol/L)")))
# Out:
# plot without title

# %%
objetive_aux <- function(D) {

    f = - objective(D)

    return(f)
}

# %%
sol = optimise(objetive_aux, interval = c(0,1))
D_opt = sol$minimum
obj_opt = -sol$objective

# %%
par(mar = c(5,7,4,2) + 0.1)
plot(D, Pb, type = "l", lwd = 4, cex.axis = 2, cex.lab = 1.8, col = "blue", xlab = expression(paste("D (",mol^{-1},")")),
      ylab = "Objetivo (mol/L)")
abline(v = D_opt, col = "red", lwd = 4)
# Out:
# plot without title

# %%
print(D_opt)
# Out:
# [1] 0.2544952

# %%
print(obj_opt)
# Out:
# [1] 20.88996
